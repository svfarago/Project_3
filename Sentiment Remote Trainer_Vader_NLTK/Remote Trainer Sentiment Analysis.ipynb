# %%
import pandas as pd

#Convert xlsx file to csv first, you may also have to resave a CSV file for the encoding (UTF-8)
df = pd.read_csv(r'RT_Responses_dataset_May2021.csv')
df.head()
# Out:
#      User: Full Name Learning Assignment: Completed On  \
# 0  1d1m0M5rr16_jenni                          6/8/2020
# 1  1d1m0M5rr16_jenni                          6/8/2020
# 2  1d1m0M5rr16_jenni                          6/8/2020
# 3  1d1m0M5rr16_jenni                          6/8/2020
# 4  1d1m0M5rr16_jenni                          6/8/2020
#
#   Learning Assignment: Learning Plan: Learning Plan Name  \
# 0              SAFe Remote Trainer (Limited Release)
# 1              SAFe Remote Trainer (Limited Release)
# 2              SAFe Remote Trainer (Limited Release)
# 3              SAFe Remote Trainer (Limited Release)
# 4              SAFe Remote Trainer (Limited Release)
#
#    Learning Assignment: Progress %  Learning Assignment: Times Launched  \
# 0                              100                                    1
# 1                              100                                    1
# 2                              100                                    1
# 3                              100                                    1
# 4                              100                                    1
#
#   Learning Assignment: Learning Plan Section: Learning Plan Section Name  \
# 0                  Lesson 5 - Teaching SAFe Remotely
# 1                  Lesson 5 - Teaching SAFe Remotely
# 2                  Lesson 5 - Teaching SAFe Remotely
# 3        Lesson 4 - Transitioning to Remote Training
# 4        Lesson 4 - Transitioning to Remote Training
#
#                                        Question Text  \
# 0  Of the SAFe common topics covered in this less...
# 1  What is one thing that could go wrong during o...
# 2  What was your biggest learning from making you...
# 3  What expert advice or tip has made the most di...
# 4  What is a best practice you use in your in-per...
#
#                                   Response Text Long
# 0     I want to see how the coin toss exercise goes.
# 1  The document sharing could not be working for ...
# 2  It takes twice as long to prep for a remote class
# 3                     Use stories to engage learners
# 4          Check in at the start and end of each day

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
#NLTK = Natural Language Tool Kit
#VADER = *not darth* Valence Aware Dictionary for Sentiment Reasoning
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\susan.farago\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df.fillna("blank", inplace = True)
df.head()
# Out:
#      User: Full Name Learning Assignment: Completed On  \
# 0  1d1m0M5rr16_jenni                          6/8/2020
# 1  1d1m0M5rr16_jenni                          6/8/2020
# 2  1d1m0M5rr16_jenni                          6/8/2020
# 3  1d1m0M5rr16_jenni                          6/8/2020
# 4  1d1m0M5rr16_jenni                          6/8/2020
#
#   Learning Assignment: Learning Plan: Learning Plan Name  \
# 0              SAFe Remote Trainer (Limited Release)
# 1              SAFe Remote Trainer (Limited Release)
# 2              SAFe Remote Trainer (Limited Release)
# 3              SAFe Remote Trainer (Limited Release)
# 4              SAFe Remote Trainer (Limited Release)
#
#    Learning Assignment: Progress %  Learning Assignment: Times Launched  \
# 0                              100                                    1
# 1                              100                                    1
# 2                              100                                    1
# 3                              100                                    1
# 4                              100                                    1
#
#   Learning Assignment: Learning Plan Section: Learning Plan Section Name  \
# 0                  Lesson 5 - Teaching SAFe Remotely
# 1                  Lesson 5 - Teaching SAFe Remotely
# 2                  Lesson 5 - Teaching SAFe Remotely
# 3        Lesson 4 - Transitioning to Remote Training
# 4        Lesson 4 - Transitioning to Remote Training
#
#                                        Question Text  \
# 0  Of the SAFe common topics covered in this less...
# 1  What is one thing that could go wrong during o...
# 2  What was your biggest learning from making you...
# 3  What expert advice or tip has made the most di...
# 4  What is a best practice you use in your in-per...
#
#                                   Response Text Long
# 0     I want to see how the coin toss exercise goes.
# 1  The document sharing could not be working for ...
# 2  It takes twice as long to prep for a remote class
# 3                     Use stories to engage learners
# 4          Check in at the start and end of each day

# %%
# Original formula used polarity score for two areas
#sid.polarity_scores(df.iloc[0]['Additional_Comments__c'])

# %%
sid.polarity_scores(df.iloc[0]['Question Text'])
#Thought I'd add the score of the question test to rank negative or positive wording.
# Out:
# {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.8173}

# %%
# Original formula used polarity score for two areas
#sid.polarity_scores(df.iloc[0]['What_can_SAI_make_easier_for_you__c'])

# %%
sid.polarity_scores(df.iloc[0]['Response Text Long'])
#Add instructor's rating of course here? Unsure I need this secondary calculation BUT it feeds formulas below
# Out:
# {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.0772}

# %%
# Just replaced original df with "Question Text"
df['question_text_scores'] = df['Question Text'].apply(lambda Impediments:sid.polarity_scores(Impediments))
df['question_text_compound'] = df['question_text_scores'].apply(lambda d:d['compound'])
df['question_text_scores'] = df['question_text_compound'].apply(lambda score: 'pos' if score >=0 else 'neg')
df.head()
# Out:
#      User: Full Name Learning Assignment: Completed On  \
# 0  1d1m0M5rr16_jenni                          6/8/2020
# 1  1d1m0M5rr16_jenni                          6/8/2020
# 2  1d1m0M5rr16_jenni                          6/8/2020
# 3  1d1m0M5rr16_jenni                          6/8/2020
# 4  1d1m0M5rr16_jenni                          6/8/2020
#
#   Learning Assignment: Learning Plan: Learning Plan Name  \
# 0              SAFe Remote Trainer (Limited Release)
# 1              SAFe Remote Trainer (Limited Release)
# 2              SAFe Remote Trainer (Limited Release)
# 3              SAFe Remote Trainer (Limited Release)
# 4              SAFe Remote Trainer (Limited Release)
#
#    Learning Assignment: Progress %  Learning Assignment: Times Launched  \
# 0                              100                                    1
# 1                              100                                    1
# 2                              100                                    1
# 3                              100                                    1
# 4                              100                                    1
#
#   Learning Assignment: Learning Plan Section: Learning Plan Section Name  \
# 0                  Lesson 5 - Teaching SAFe Remotely
# 1                  Lesson 5 - Teaching SAFe Remotely
# 2                  Lesson 5 - Teaching SAFe Remotely
# 3        Lesson 4 - Transitioning to Remote Training
# 4        Lesson 4 - Transitioning to Remote Training
#
#                                        Question Text  \
# 0  Of the SAFe common topics covered in this less...
# 1  What is one thing that could go wrong during o...
# 2  What was your biggest learning from making you...
# 3  What expert advice or tip has made the most di...
# 4  What is a best practice you use in your in-per...
#
#                                   Response Text Long  \
# 0     I want to see how the coin toss exercise goes.
# 1  The document sharing could not be working for ...
# 2  It takes twice as long to prep for a remote class
# 3                     Use stories to engage learners
# 4          Check in at the start and end of each day
#
#                                    scores_additional  compound_additional  \
# 0  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...               0.8173
# 1  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...               0.1779
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               0.0000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               0.0000
# 4  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...               0.6369
#
#   score_additional                    question_text_scores_additional  \
# 0              pos  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...
# 1              pos  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...
# 2              pos  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3              pos  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4              pos  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
#
#    question_text_compound_additional question_text_score_additional  \
# 0                             0.8173                            pos
# 1                             0.1779                            pos
# 2                             0.0000                            pos
# 3                             0.0000                            pos
# 4                             0.6369                            pos
#
#                                question_text_scoresl question_text_scores  \
# 0  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...                  pos
# 1  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...                  pos
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...                  pos
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...                  pos
# 4  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...                  pos
#
#    question_text_compound
# 0                  0.8173
# 1                  0.1779
# 2                  0.0000
# 3                  0.0000
# 4                  0.6369

# %%
# Just replaced original df with "Response Text Long"
df['response_text_scores'] = df['Response Text Long'].apply(lambda Impediments:sid.polarity_scores(Impediments))
df['response_text_compound'] = df['response_text_scores'].apply(lambda d:d['compound'])
df['response_text_scores'] = df['response_text_compound'].apply(lambda score: 'pos' if score >=0 else 'neg')
df.head()
# Out:
#      User: Full Name Learning Assignment: Completed On  \
# 0  1d1m0M5rr16_jenni                          6/8/2020
# 1  1d1m0M5rr16_jenni                          6/8/2020
# 2  1d1m0M5rr16_jenni                          6/8/2020
# 3  1d1m0M5rr16_jenni                          6/8/2020
# 4  1d1m0M5rr16_jenni                          6/8/2020
#
#   Learning Assignment: Learning Plan: Learning Plan Name  \
# 0              SAFe Remote Trainer (Limited Release)
# 1              SAFe Remote Trainer (Limited Release)
# 2              SAFe Remote Trainer (Limited Release)
# 3              SAFe Remote Trainer (Limited Release)
# 4              SAFe Remote Trainer (Limited Release)
#
#    Learning Assignment: Progress %  Learning Assignment: Times Launched  \
# 0                              100                                    1
# 1                              100                                    1
# 2                              100                                    1
# 3                              100                                    1
# 4                              100                                    1
#
#   Learning Assignment: Learning Plan Section: Learning Plan Section Name  \
# 0                  Lesson 5 - Teaching SAFe Remotely
# 1                  Lesson 5 - Teaching SAFe Remotely
# 2                  Lesson 5 - Teaching SAFe Remotely
# 3        Lesson 4 - Transitioning to Remote Training
# 4        Lesson 4 - Transitioning to Remote Training
#
#                                        Question Text  \
# 0  Of the SAFe common topics covered in this less...
# 1  What is one thing that could go wrong during o...
# 2  What was your biggest learning from making you...
# 3  What expert advice or tip has made the most di...
# 4  What is a best practice you use in your in-per...
#
#                                   Response Text Long  \
# 0     I want to see how the coin toss exercise goes.
# 1  The document sharing could not be working for ...
# 2  It takes twice as long to prep for a remote class
# 3                     Use stories to engage learners
# 4          Check in at the start and end of each day
#
#                                    scores_additional  compound_additional  \
# 0  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...               0.8173
# 1  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...               0.1779
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               0.0000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               0.0000
# 4  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...               0.6369
#
#   score_additional                    question_text_scores_additional  \
# 0              pos  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...
# 1              pos  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...
# 2              pos  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3              pos  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4              pos  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...
#
#    question_text_compound_additional question_text_score_additional  \
# 0                             0.8173                            pos
# 1                             0.1779                            pos
# 2                             0.0000                            pos
# 3                             0.0000                            pos
# 4                             0.6369                            pos
#
#                                question_text_scoresl question_text_scores  \
# 0  {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'comp...                  pos
# 1  {'neg': 0.065, 'neu': 0.814, 'pos': 0.121, 'co...                  pos
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...                  pos
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...                  pos
# 4  {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'comp...                  pos
#
#    question_text_compound response_text_scores  response_text_compound
# 0                  0.8173                  pos                  0.0772
# 1                  0.1779                  pos                  0.0000
# 2                  0.0000                  pos                  0.0000
# 3                  0.0000                  pos                  0.3400
# 4                  0.6369                  pos                  0.0000

# %%
df.to_csv(r'RT Sentiment Output_May2021.csv')
